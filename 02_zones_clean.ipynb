# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Last_wts_flow_zone_cleaned.csv

# %%
# Local Network
#df = pd.read_csv(r"H:\R&D\Research\Commerce local\Data Analytics\Flux piétons\AFP WTS Tableau report\Data\last_wts_flow_zone_cleaned.csv", sep=",")

# %%
#last_wts_flow_zone_cleaned.csv
zones = pd.read_csv(r"./data/last_wts_flow_zone_cleaned.csv", sep=",")
zones.tail(60)
# Out:
#                                  nom_capteur             Quartier  \
# 12             GRAND_PLACE_2 - La vapotheque          grand place
# 13     GRAND_PLACE_1 - La Belgique gourmande          grand place
# 14                  GRAND_PLACE_3 - Proximus          grand place
# 15         CF - UCCLE_CENTRE - Glacier Lanni         uccle centre
# 16             CF - UCCLE_CENTRE - Ai6Angoli         uccle centre
# 17                CF - UCCLE_CENTRE - Mikado         uccle centre
# 18               CF - UCCLE_CENTRE - Veritas         uccle centre
# 19           CF - UCCLE_CENTRE - Binamé & Co         uccle centre
# 20                SABLON_1 - Maison Holemans               sablon
# 21               SABLON - L'atelier en herbe               sablon
# 22                   PLACE_WIENER_1 - La Bas         place wiener
# 23   SAINT_JULIEN_1 - Librairie Saint-Julien         saint julien
# 24               DE_WAND_1 - Olivier Dashkin              de wand
# 25                     UCCLE_1 - OPTIL Uccle                uccle
# 26       RUE_DE_NAMUR_1 - The Marie's Corner         rue de namur
# 27                  RUE_DE_NAMUR_2 - Versace         rue de namur
# 28    LEMONNIER_1 - Centre medical lemonnier            lemonnier
# 29                     LEMONNIER_2 - Yaddcom            lemonnier
# 30                GEORGES_HENRI_1 - Ghyoptic        georges henri
# 31                   DAILLY_1 - Optic Dailly               dailly
# 32                 PLACE_KEYM_1 - Bloom Moon           place keym
# 33                         CONGRES - Inksane              congres
# 34        CIMETIÈRE_D'IXELLES_1 - Pop & Shop  cimetière d'ixelles
# 35                  CUREGHEM_1 - Slina Hotel             cureghem
# 36               MONT_DES_ARTS_1 - Art Thema        mont des arts
# 37                  BOCKSTAEL_1 - Alfa Jeans            bockstael
# 38          MOLENBEEK_1 - Ideal Cash & Carry            molenbeek
# 39                         RUE_NEUVE_1 - C&A            rue neuve
# 40      CF - SAINT GILLES - Boucherie Segers         saint gilles
# 41    CF - SAINT GILLES - Librairie Novembre         saint gilles
# 42         CF - SAINT GILLES - Haute tension         saint gilles
# 43     CF - SAINT GILLES - Salon de coiffure         saint gilles
# 44      CF - SAINT GILLES - Les Petits Riens         saint gilles
# 45  CF - SAINT GILLES - Batist Titre Service         saint gilles
# 46         SAINT GILLES_Le monde à mes pieds                  NaN
# 47          PLACE_JOURDAN_1 - Au Vatel (50m)        place jourdan
# 48                        FLAGEY_1 - Dim yum               flagey
# 49         LOUISE_1 - Elisabeth Chocolaterie               louise
# 50                  MIROIR_1 - Il Cappuccino               miroir
# 51                CF - MIROIR - La Ressource               miroir
# 52           CF - MIROIR - Auberge Espagnole               miroir
# 53                CF - MIROIR - Petits Riens               miroir
# 54                      CF - MIROIR - Inkfox               miroir
# 55                        VISMET_1 - CIG-ART               vismet
# 56            HENRI_CONSCIENCE_1 - Optigroup     henri conscience
# 57          PORTES_DE_NAMUR_1 - Maison Dorée      portes de namur
# 58                     SCHWEITZER_1 - Belkdo           schweitzer
# 59                SAINT_JOB_1 - Espace Photo            saint job
# 60                VANDERKINDERE_1 - The Barn        vanderkindere
# 61                 BAILLI_1 - Parfum d'Ambre               bailli
# 62         MIDI_1 - Logistic Express Service                 midi
# 63                    LUXEMBOURG - Pharmacie           luxembourg
# 64                     PADUWA_1 - Le Fraysse               paduwa
# 65      MAROLLES_1 - Ebenisterie Deschuytere             marolles
# 66                MAROLLES_2 - Machao Design             marolles
# 67        STOCKEL_1 - Elisabeth Chocolaterie              stockel
# 68               TONGRES_1 - Proximus Center              tongres
# 69                        DANSAERT_1 - K-Way             dansaert
# 70            LA_CHASSE_1 - Optical Discount            la chasse
# 71                       TOISON_DOR - Krefel           toison dor
#
#     id_capteur_quartier  zone_id type_capteur                       address  \
# 12                    1    10144         fixe  Rue du Marché aux Herbes, 31
# 13                    2    10141         fixe           Rue de la Colline 9
# 14                    3    10147         fixe          Boulevard Anspach 26
# 15                    1    12578   temporaire           Rue Xavier De Bue 1
# 16                    2    12566   temporaire            Rue du Postillon 9
# 17                    3    12564   temporaire             Rue du Doyenné 75
# 18                    4    12576   temporaire      Chaussée d'Alsemberg 750
# 19                    5    12565   temporaire         Chau. d'Alsemberg 707
# 20                    1    10156         fixe       Place du Grand Sablon 4
# 21                    2    14202         fixe        Pl. du Grand Sablon 36
# 22                    1    10197         fixe            Rue Middelbourg 86
# 23                    1    10195         fixe        Chaussée de Wavre 1285
# 24                    1    10161         fixe                Rue De Wand 57
# 25                    1    10200         fixe          Rue Xavier De Bue 40
# 26                    1    10153         fixe              Rue de Namur\t39
# 27                    2    10154         fixe       Boulevard de Waterloo 7
# 28                    1    10148         fixe       Bd Maurice Lemonnier 94
# 29                    2    10149         fixe       Avenue de Stalingrad 63
# 30                    1    10203         fixe      Avenue Georges Henri 227
# 31                    1    10174         fixe                Av. Dailly 255
# 32                    1    10196         fixe          Place Eugène Keym 19
# 33                    1    13485         fixe           Rue de la Presse, 3
# 34                    1    10180         fixe      Avenue de l'Université 5
# 35                    1    10185         fixe             Chau. de Mons 117
# 36                    1    10152         fixe        Rue de la Madeleine 59
# 37                    1    10160         fixe       Rue Marie-Christine 160
# 38                    1    10188         fixe          Chaussée de Gand\t33
# 39                    1    10155         fixe                Nieuwstraat 29
# 40                    1    13196   temporaire               Rue Jourdan 187
# 41                    2    13202   temporaire                Rue du Fort 38
# 42                    3    13194   temporaire       Chaussée de Waterloo 97
# 43                    4    13198   temporaire       Chaussée de Waterloo 24
# 44                    5    13200   temporaire      Chaussée de Waterloo 149
# 45                    6    13204   temporaire        Avenue Jean Volders 16
# 46                    1    14204         fixe          Chau. de Waterloo 62
# 47                    1    10177         fixe             Place Jourdan\t27
# 48                    1    10181         fixe         Rue Maria Malibran 20
# 49                    1    10182         fixe              Avenue Louise 49
# 50                    1    10191         fixe            Pl. Reine Astrid 1
# 51                    2    13756   temporaire      Rue Pierre Timmermans 45
# 52                    3    13755   temporaire           Rue Léon Theodor 22
# 53                    4    13757   temporaire            Chau. de Jette 683
# 54                    5    13754   temporaire              Av. de Jette 276
# 55                    1    10159         fixe       Rue Sainte-Catherine 9A
# 56                    1    10192         fixe       Avenue H. Conscience 94
# 57                    1    10183         fixe         Chaussée d'Ixelles 14
# 58                    1    10190         fixe            Rue de l'Eglise 17
# 59                    1    10199         fixe           Pl. de Saint-Job 32
# 60                    1    10201         fixe         Rue Vanderkindere 166
# 61                    1    10179         fixe              Rue du Bailli 45
# 62                    1    10186         fixe              Rue Brogniez 115
# 63                    1    13487         fixe         Rue du Luxembourg, 21
# 64                    1    10193         fixe       Chaussée de Louvain 896
# 65                    1    10150         fixe                  Rue Haute 77
# 66                    2    10151         fixe                 Rue Blaes 156
# 67                    1    10194         fixe           Rue de l'Eglise 163
# 68                    1    10178         fixe            Rue des Tongres 63
# 69                    1    10137         fixe       Rue Antoine Dansaert 33
# 70                    1    10176         fixe         Chaussée de Wavre 748
# 71                    1    12144         fixe      Av. de la Toison d'Or 36
#
#     zipcode                   city    longitude      latitude
# 12     1000              Bruxelles  4,352431166  50,847679588
# 13     1000              Bruxelles  4,353672559  50,846749599
# 14     1000              Bruxelles  4,351509071  50,849902409
# 15     1180                  Uccle  4,334781160  50,803438911
# 16     1180                  Uccle  4,339558962  50,802853505
# 17     1180                  Uccle  4,340460192  50,803146687
# 18     1180                  Uccle  4,336622848  50,800882673
# 19     1180                  Uccle  4,336608132  50,805304813
# 20     1000              Bruxelles  4,354444920  50,841534314
# 21     1000              Bruxelles  4,354685998  50,840695768
# 22     1170    Watermael-Boitsfort  4,418385958  50,794646732
# 23     1160              Auderghem  4,407665155  50,821085474
# 24     1000              Bruxelles  4,358517230  50,897015960
# 25     1180                  Uccle  4,337566450  50,803517463
# 26     1000              Bruxelles  4,359823772  50,840151446
# 27     1000              Bruxelles  4,361013177  50,838650973
# 28     1000              Bruxelles  4,344364145  50,843020475
# 29     1000              Bruxelles  4,343044017  50,840901141
# 30     1200   Woluwe-Saint-Lambert  4,416124528  50,844632515
# 31     1030             Schaerbeek  4,386972143  50,852838003
# 32     1170    Watermael-Boitsfort  4,403568962  50,808803821
# 33     1000              Bruxelles  4,366463813  50,849270570
# 34     1050                Ixelles  4,389272032  50,815568095
# 35     1070             Anderlecht  4,333001993  50,843203055
# 36     1000              Bruxelles  4,355345935  50,844771346
# 37     1000              Bruxelles  4,352093718  50,875980813
# 38     1080   Molenbeek-Saint-Jean  4,339266009  50,853477517
# 39     1000              Bruxelles  4,354791836  50,851530266
# 40     1060           Saint-Gilles  4,346746467  50,831111660
# 41     1060           Saint-Gilles  4,342998037  50,828874213
# 42     1060           Saint-Gilles  4,344184625  50,829137225
# 43     1060           Saint-Gilles  4,344970511  50,831963924
# 44     1060           Saint-Gilles  4,344230965  50,827728624
# 45     1060           Saint-Gilles  4,343341827  50,832233660
# 46     1060              Bruxelles  4,344784311  50,830782032
# 47     1040              Etterbeek  4,381796442  50,837021814
# 48     1050                Ixelles  4,372513939  50,829284645
# 49     1050                Ixelles  4,356946377  50,833806875
# 50     1090                  Jette  4,324728847  50,873023431
# 51     1090                  Jette  4,323777962  50,873731347
# 52     1090                  Jette  4,326025820  50,873893378
# 53     1090                  Jette  4,325895729  50,872373969
# 54     1090                  Jette  4,324184698  50,871885966
# 55     1000              Bruxelles  4,348513239  50,849822112
# 56     1140                  Evere  4,399867635  50,868981927
# 57     1050                Ixelles  4,362212082  50,837801025
# 58     1082  Berchem-Sainte-Agathe  4,295443813  50,864147556
# 59     1180                  Uccle  4,365755139  50,794544230
# 60     1180                  Uccle  4,346220899  50,813883263
# 61     1050                Ixelles  4,361183955  50,826340639
# 62     1070             Anderlecht  4,334073533  50,839806681
# 63     1000              Bruxelles  4,367996079  50,840064698
# 64     1140                  Evere  4,412873915  50,858579524
# 65     1000              Bruxelles  4,350939694  50,839987957
# 66     1000              Bruxelles  4,347312942  50,837670242
# 67     1150    Woluwe-Saint-Pierre  4,465880803  50,840226884
# 68     1040              Etterbeek  4,400899118  50,840325189
# 69     1000              Bruxelles  4,347356044  50,849466081
# 70     1040              Etterbeek  4,391342028  50,829791461
# 71     1050                Ixelles  4,357533672  50,836358770

# %%
zones.zone_id.nunique()
# Out:
# 72

# %%
# Erase 'CF' of the sensor name 
zones.insert(1,'nom_capteur2', (zones["nom_capteur"].str.replace("^CF\s-","", regex=True)))
# Split the sensor name and the shop
zones[['name','shop']] = zones.nom_capteur2.str.split(" - ", expand = True)
# Sort DataFrame by zone
zones = zones.sort_values(by='zone_id').reset_index(drop=True)
# Capitalize the first letter of each word of the Quartier variable
zones.Quartier = zones.Quartier.str.title()

# %%
zones = zones.loc[:, ['zone_id', 'nom_capteur', 'Quartier', 'shop', 'id_capteur_quartier',
       'type_capteur', 'address', 'zipcode', 'city', 'longitude','latitude']]
zones.tail(4)
# Out:
#     zone_id                              nom_capteur      Quartier  \
# 68    14211       CF - SAINT GUIDON - One Hour Photo  Saint Guidon
# 69    14212    CF - SAINT GUIDON - Librairie Libburo  Saint Guidon
# 70    14213       CF - SAINT GUIDON - Cordonnerie 47  Saint Guidon
# 71    14214  CF - SAINT GUIDON - Librairie Vaillance  Saint Guidon
#
#                    shop  id_capteur_quartier type_capteur             address  \
# 68       One Hour Photo                    3   temporaire      Rue Wayez, 177
# 69    Librairie Libburo                    4   temporaire  Rue de Formanoir 6
# 70       Cordonnerie 47                    2   temporaire       Rue Wayez, 47
# 71  Librairie Vaillance                    5   temporaire      Cr St Guidon 1
#
#     zipcode        city    longitude      latitude
# 68     1070  Anderlecht  4,308356545  50,835217138
# 69     1070  Anderlecht  4,307457141  50,835487097
# 70     1070  Anderlecht  4,314975859  50,836314409
# 71     1070  Anderlecht  4,306341390  50,834908307

# %%
# .csv file
zones.to_csv('./assets/zones_modif.csv')

# %% [markdown]
# ## Insights

# %%
zones.Quartier.nunique()
# Out:
# 47

# %%
zones.zone_id.nunique()
# Out:
# 72

# %%
zones.type_capteur.value_counts()
# Out:
# fixe          53
# temporaire    19
# Name: type_capteur, dtype: int64

# %%
zones['id_capteur_quartier'].value_counts()
# Out:
# 1    48
# 2    10
# 3     5
# 5     4
# 4     4
# 6     1
# Name: id_capteur_quartier, dtype: int64

# %%
w = zones.groupby(['zone_id','type_capteur']).agg({'Quartier': ['unique']})
w
# Out:
#                             Quartier
#                               unique
# zone_id type_capteur
# 10137   fixe              [Dansaert]
# 10141   fixe           [Grand Place]
# 10144   fixe           [Grand Place]
# 10147   fixe           [Grand Place]
# 10148   fixe             [Lemonnier]
# ...                              ...
# 14204   fixe                   [nan]
# 14211   temporaire    [Saint Guidon]
# 14212   temporaire    [Saint Guidon]
# 14213   temporaire    [Saint Guidon]
# 14214   temporaire    [Saint Guidon]
#
# [72 rows x 1 columns]

# %%
z = zones.groupby(['Quartier']).agg({'zone_id': ['unique'], 'type_capteur': ['unique']})
z
# Out:
#                                                         zone_id  \
#                                                          unique
# Quartier
# Bailli                                                  [10179]
# Bockstael                                               [10160]
# Cimetière D'Ixelles                                     [10180]
# Congres                                                 [13485]
# Cureghem                                                [10185]
# Dailly                                                  [10174]
# Dansaert                                                [10137]
# De Wand                                                 [10161]
# Flagey                                                  [10181]
# Georges Henri                                           [10203]
# Grand Place                               [10141, 10144, 10147]
# Helmet                                                  [10175]
# Henri Conscience                                        [10192]
# La Bascule                                              [10198]
# La Chasse                                               [10176]
# Lemonnier                                        [10148, 10149]
# Louise                                                  [10182]
# Luxembourg                                              [13487]
# Madou                                                   [10204]
# Marolles                                         [10150, 10151]
# Midi                                                    [10186]
# Miroir                      [10191, 13754, 13755, 13756, 13757]
# Molenbeek                                               [10188]
# Mont Des Arts                                           [10152]
# Paduwa                                                  [10193]
# Place Jourdan                                           [10177]
# Place Keym                                              [10196]
# Place Wiener                                            [10197]
# Portes De Namur                                         [10183]
# Rue De Namur                                     [10153, 10154]
# Rue Neuve                                               [10155]
# Sablon                                           [10156, 14202]
# Saint Denis                                             [10202]
# Saint Gilles         [13194, 13196, 13198, 13200, 13202, 13204]
# Saint Guidon                [10187, 14211, 14212, 14213, 14214]
# Saint Jacques                                    [10157, 10158]
# Saint Job                                               [10199]
# Saint Julien                                            [10195]
# Schweitzer                                              [10190]
# Simonis                                                 [10189]
# Stockel                                                 [10194]
# Toison Dor                                              [12144]
# Tongres                                                 [10178]
# Uccle                                                   [10200]
# Uccle Centre                [12564, 12565, 12566, 12576, 12578]
# Vanderkindere                                           [10201]
# Vismet                                                  [10159]
#
#                            type_capteur
#                                  unique
# Quartier
# Bailli                           [fixe]
# Bockstael                        [fixe]
# Cimetière D'Ixelles              [fixe]
# Congres                          [fixe]
# Cureghem                         [fixe]
# Dailly                           [fixe]
# Dansaert                         [fixe]
# De Wand                          [fixe]
# Flagey                           [fixe]
# Georges Henri                    [fixe]
# Grand Place                      [fixe]
# Helmet                           [fixe]
# Henri Conscience                 [fixe]
# La Bascule                       [fixe]
# La Chasse                        [fixe]
# Lemonnier                        [fixe]
# Louise                           [fixe]
# Luxembourg                       [fixe]
# Madou                            [fixe]
# Marolles                         [fixe]
# Midi                             [fixe]
# Miroir               [fixe, temporaire]
# Molenbeek                        [fixe]
# Mont Des Arts                    [fixe]
# Paduwa                           [fixe]
# Place Jourdan                    [fixe]
# Place Keym                       [fixe]
# Place Wiener                     [fixe]
# Portes De Namur                  [fixe]
# Rue De Namur                     [fixe]
# Rue Neuve                        [fixe]
# Sablon                           [fixe]
# Saint Denis                      [fixe]
# Saint Gilles               [temporaire]
# Saint Guidon         [fixe, temporaire]
# Saint Jacques                    [fixe]
# Saint Job                        [fixe]
# Saint Julien                     [fixe]
# Schweitzer                       [fixe]
# Simonis                          [fixe]
# Stockel                          [fixe]
# Toison Dor                       [fixe]
# Tongres                          [fixe]
# Uccle                            [fixe]
# Uccle Centre               [temporaire]
# Vanderkindere                    [fixe]
# Vismet                           [fixe]

# %%
y = zones.groupby('city')['Quartier'].count()
y
# Out:
# city
# Anderlecht                7
# Auderghem                 1
# Berchem-Sainte-Agathe     1
# Bruxelles                21
# Etterbeek                 3
# Evere                     2
# Forest                    1
# Ixelles                   6
# Jette                     5
# Koekelberg                1
# Molenbeek-Saint-Jean      1
# Saint-Gilles              6
# Saint-Josse-ten-Noode     1
# Schaerbeek                2
# Uccle                     9
# Watermael-Boitsfort       2
# Woluwe-Saint-Lambert      1
# Woluwe-Saint-Pierre       1
# Name: Quartier, dtype: int64

# %%
zones.city.nunique()
# Out:
# 18

# %%
zones.city.unique()
# Out:
# array(['Bruxelles', 'Schaerbeek', 'Etterbeek', 'Ixelles', 'Anderlecht',
#        'Molenbeek-Saint-Jean', 'Koekelberg', 'Berchem-Sainte-Agathe',
#        'Jette', 'Evere', 'Woluwe-Saint-Pierre', 'Auderghem',
#        'Watermael-Boitsfort', 'Uccle', 'Forest', 'Woluwe-Saint-Lambert',
#        'Saint-Josse-ten-Noode', 'Saint-Gilles'], dtype=object)

# %%
# city = municipalities
b = zones.groupby('zipcode')['city'].value_counts()
b
# Out:
# zipcode  city
# 1000     Bruxelles                21
# 1030     Schaerbeek                2
# 1040     Etterbeek                 3
# 1050     Ixelles                   6
# 1060     Saint-Gilles              6
#          Bruxelles                 1
# 1070     Anderlecht                7
# 1080     Molenbeek-Saint-Jean      1
# 1081     Koekelberg                1
# 1082     Berchem-Sainte-Agathe     1
# 1090     Jette                     5
# 1140     Evere                     2
# 1150     Woluwe-Saint-Pierre       1
# 1160     Auderghem                 1
# 1170     Watermael-Boitsfort       2
# 1180     Uccle                     9
# 1190     Forest                    1
# 1200     Woluwe-Saint-Lambert      1
# 1210     Saint-Josse-ten-Noode     1
# Name: city, dtype: int64
